# %%
# This project will be open-ended to cater to your own person creative workflow.

# Using the requests package in Python, connect to the PokeAPI at https://pokeapi.co/ to build an
# encyclopedia of Pokemon i.e. a Pokedex

# Your objective: Accumulate a Pokedex of 20 different Pokemon in which each entry specifies the Pokemon's
# height, weight and abilities and type (Fire, Water, Flying, Mystic, etc.)

# %%
import requests

pikachu = []

data= requests.get('https://pokeapi.co/api/v2/pokemon/pikachu').json()

ability=[(data['abilities'][0]['ability']['name']),(data['abilities'][1]['ability']['name'])]
ty=[data['types'][0]['type']['name']]
he=[data['height']]
we=[data["weight"]]

pikachu.append({'abilities':ability})
pikachu.append({'height':he})
pikachu.append({'weight':we})
pikachu.append({'types':ty})

pikachu

pidgey = []

data= requests.get('https://pokeapi.co/api/v2/pokemon/pidgey').json()

ability=[(data['abilities'][0]['ability']['name']),(data['abilities'][1]['ability']['name'])]
ty=[data['types'][0]['type']['name']]
he=[data['height']]
we=[data["weight"]]

pidgey.append({'abilities':ability})
pidgey.append({'height':he})
pidgey.append({'weight':we})
pidgey.append({'types':ty})

squirtle = []

data= requests.get('https://pokeapi.co/api/v2/pokemon/squirtle').json()

ability=[(data['abilities'][0]['ability']['name']),(data['abilities'][1]['ability']['name'])]
ty=[data['types'][0]['type']['name']]
he=[data['height']]
we=[data["weight"]]

squirtle.append({'abilities':ability})
squirtle.append({'height':he})
squirtle.append({'weight':we})
squirtle.append({'types':ty})

charmander = []

data= requests.get('https://pokeapi.co/api/v2/pokemon/charmander').json()

ability=[(data['abilities'][0]['ability']['name']),(data['abilities'][1]['ability']['name'])]
ty=[data['types'][0]['type']['name']]
he=[data['height']]
we=[data["weight"]]

charmander.append({'abilities':ability})
charmander.append({'height':he})
charmander.append({'weight':we})
charmander.append({'types':ty})

bulbasaur = []

data= requests.get('https://pokeapi.co/api/v2/pokemon/bulbasaur').json()

ability=[(data['abilities'][0]['ability']['name']),(data['abilities'][1]['ability']['name'])]
ty=[data['types'][0]['type']['name']]
he=[data['height']]
we=[data["weight"]]

bulbasaur.append({'abilities':ability})
bulbasaur.append({'height':he})
bulbasaur.append({'weight':we})
bulbasaur.append({'types':ty})


meowth = []

data= requests.get('https://pokeapi.co/api/v2/pokemon/meowth').json()

ability=[(data['abilities'][0]['ability']['name']),(data['abilities'][1]['ability']['name'])]
ty=[data['types'][0]['type']['name']]
he=[data['height']]
we=[data["weight"]]

meowth.append({'abilities':ability})
meowth.append({'height':he})
meowth.append({'weight':we})
meowth.append({'types':ty})

dragonite = []

data= requests.get('https://pokeapi.co/api/v2/pokemon/dragonite').json()

ability=[(data['abilities'][0]['ability']['name']),(data['abilities'][1]['ability']['name'])]
ty=[data['types'][0]['type']['name']]
he=[data['height']]
we=[data["weight"]]

dragonite.append({'abilities':ability})
dragonite.append({'height':he})
dragonite.append({'weight':we})
dragonite.append({'types':ty})

eevee = []

data= requests.get('https://pokeapi.co/api/v2/pokemon/eevee').json()

ability=[(data['abilities'][0]['ability']['name']),(data['abilities'][1]['ability']['name'])]
ty=[data['types'][0]['type']['name']]
he=[data['height']]
we=[data["weight"]]

eevee.append({'abilities':ability})
eevee.append({'height':he})
eevee.append({'weight':we})
eevee.append({'types':ty})

gloom = []

data= requests.get('https://pokeapi.co/api/v2/pokemon/gloom').json()

ability=[(data['abilities'][0]['ability']['name']),(data['abilities'][1]['ability']['name'])]
ty=[data['types'][0]['type']['name']]
he=[data['height']]
we=[data["weight"]]

gloom.append({'abilities':ability})
gloom.append({'height':he})
gloom.append({'weight':we})
gloom.append({'types':ty})

charizard = []

data= requests.get('https://pokeapi.co/api/v2/pokemon/charizard').json()

ability=[(data['abilities'][0]['ability']['name']),(data['abilities'][1]['ability']['name'])]
ty=[data['types'][0]['type']['name']]
he=[data['height']]
we=[data["weight"]]

charizard.append({'abilities':ability})
charizard.append({'height':he})
charizard.append({'weight':we})
charizard.append({'types':ty})

cubone = []

data= requests.get('https://pokeapi.co/api/v2/pokemon/cubone').json()

ability=[(data['abilities'][0]['ability']['name']),(data['abilities'][1]['ability']['name'])]
ty=[data['types'][0]['type']['name']]
he=[data['height']]
we=[data["weight"]]

cubone.append({'abilities':ability})
cubone.append({'height':he})
cubone.append({'weight':we})
cubone.append({'types':ty})

mew = []

data= requests.get('https://pokeapi.co/api/v2/pokemon/mew').json()

ability=[(data['abilities'][0]['ability']['name'])]
ty=[data['types'][0]['type']['name']]
he=[data['height']]
we=[data["weight"]]

mew.append({'abilities':ability})
mew.append({'height':he})
mew.append({'weight':we})
mew.append({'types':ty})

abra = []

data= requests.get('https://pokeapi.co/api/v2/pokemon/abra').json()

ability=[(data['abilities'][0]['ability']['name'])]
ty=[data['types'][0]['type']['name']]
he=[data['height']]
we=[data["weight"]]

abra.append({'abilities':ability})
abra.append({'height':he})
abra.append({'weight':we})
abra.append({'types':ty})

gengar = []

data= requests.get('https://pokeapi.co/api/v2/pokemon/gengar').json()

ability=[(data['abilities'][0]['ability']['name'])]
ty=[data['types'][0]['type']['name']]
he=[data['height']]
we=[data["weight"]]

gengar.append({'abilities':ability})
gengar.append({'height':he})
gengar.append({'weight':we})
gengar.append({'types':ty})

lapras = []

data= requests.get('https://pokeapi.co/api/v2/pokemon/lapras').json()

ability=[(data['abilities'][0]['ability']['name'])]
ty=[data['types'][0]['type']['name']]
he=[data['height']]
we=[data["weight"]]

lapras.append({'abilities':ability})
lapras.append({'height':he})
lapras.append({'weight':we})
lapras.append({'types':ty})

zapdos = []

data= requests.get('https://pokeapi.co/api/v2/pokemon/zapdos').json()

ability=[(data['abilities'][0]['ability']['name'])]
ty=[data['types'][0]['type']['name']]
he=[data['height']]
we=[data["weight"]]

zapdos.append({'abilities':ability})
zapdos.append({'height':he})
zapdos.append({'weight':we})
zapdos.append({'types':ty})
#
psyduck = []

data= requests.get('https://pokeapi.co/api/v2/pokemon/psyduck').json()

ability=[(data['abilities'][0]['ability']['name'])]
ty=[data['types'][0]['type']['name']]
he=[data['height']]
we=[data["weight"]]

psyduck.append({'abilities':ability})
psyduck.append({'height':he})
psyduck.append({'weight':we})
psyduck.append({'types':ty})

poliwrath = []

data= requests.get('https://pokeapi.co/api/v2/pokemon/poliwrath').json()

ability=[(data['abilities'][0]['ability']['name'])]
ty=[data['types'][0]['type']['name']]
he=[data['height']]
we=[data["weight"]]

poliwrath.append({'abilities':ability})
poliwrath.append({'height':he})
poliwrath.append({'weight':we})
poliwrath.append({'types':ty})

geodude = []

data= requests.get('https://pokeapi.co/api/v2/pokemon/geodude').json()

ability=[(data['abilities'][0]['ability']['name'])]
ty=[data['types'][0]['type']['name']]
he=[data['height']]
we=[data["weight"]]

geodude.append({'abilities':ability})
geodude.append({'height':he})
geodude.append({'weight':we})
geodude.append({'types':ty})

mankey = []

data= requests.get('https://pokeapi.co/api/v2/pokemon/mankey').json()

ability=[(data['abilities'][0]['ability']['name'])]
ty=[data['types'][0]['type']['name']]
he=[data['height']]
we=[data["weight"]]

mankey.append({'abilities':ability})
mankey.append({'height':he})
mankey.append({'weight':we})
mankey.append({'types':ty})


pokedex={}
pokedex['pikachu']=pikachu
pokedex['pidgey']=pidgey
pokedex['squirtle']=squirtle
pokedex['charmander']=charmander
pokedex['bulbasaur']=bulbasaur
pokedex['meowth']=meowth
pokedex['dragonite']=dragonite
pokedex['squirtle']=squirtle
pokedex['eevee']=eevee
pokedex['gloom']=gloom
pokedex['charizard']=charizard
pokedex['cubone']=cubone
pokedex['mew']=mew
pokedex['abra']=abra
pokedex['gengar']=gengar
pokedex['lapras']=lapras
pokedex['zapdos']=zapdos
pokedex['psyduck']=psyduck
pokedex['poliwrath']=poliwrath
pokedex['mankey']=mankey
pokedex['geodude']=geodude

pokedex
# Out:
# {'pikachu': [{'abilities': ['static', 'lightning-rod']},
#   {'height': [4]},
#   {'weight': [60]},
#   {'types': ['electric']}],
#  'pidgey': [{'abilities': ['keen-eye', 'tangled-feet']},
#   {'height': [3]},
#   {'weight': [18]},
#   {'types': ['normal']}],
#  'squirtle': [{'abilities': ['torrent', 'rain-dish']},
#   {'height': [5]},
#   {'weight': [90]},
#   {'types': ['water']}],
#  'charmander': [{'abilities': ['blaze', 'solar-power']},
#   {'height': [6]},
#   {'weight': [85]},
#   {'types': ['fire']}],
#  'bulbasaur': [{'abilities': ['overgrow', 'chlorophyll']},
#   {'height': [7]},
#   {'weight': [69]},
#   {'types': ['grass']}],
#  'meowth': [{'abilities': ['pickup', 'technician']},
#   {'height': [4]},
#   {'weight': [42]},
#   {'types': ['normal']}],
#  'dragonite': [{'abilities': ['inner-focus', 'multiscale']},
#   {'height': [22]},
#   {'weight': [2100]},
#   {'types': ['dragon']}],
#  'eevee': [{'abilities': ['run-away', 'adaptability']},
#   {'height': [3]},
# ...

# %%
print(pokedex['geodude'])
# Out:
# [{'abilities': ['rock-head']}, {'height': [4]}, {'weight': [200]}, {'types': ['rock']}]

# %%
import requests, pprint
from IPython.display import clear_output as co




class Pokemon:
    _all=[]
    def __init__(self,name=None,abilities=None,types=None,height=None,weight=None)
        self.name=name
        if abilities is None:
            self.abilities=[]        
        else:
            self.abilites = abilites
        if types is None:
            self.types = []
        else:
            self.types = types
        self.height=height
        self.weight=weight
        self._all.append(self)
        
        ####FROM MIGUEL GRINBERG
    def from_dict(self,data):
        for field in ['name', 'abilities','height','weight']:
            if field in data:
                setattr(self, field, data[field])
                
    def __repr__(self):
        return f'<Pokemon: {self.name}>'
    
    def __str__(self):
        return f'{self.name}'

class Pokedex:
    pass
    
    @classmethod
    def instructions(self):
        print("""Type 'show' to view Pokedex.
Type 'quit' to exit the Pokedex.
Type 'sort' to view a categorized version of your Pokedex.""")
    
    # prompt for some input to add in a Pokemon's name.
    
    # Check if the Pokemon we want to add has already been found in the Pokedex
        
    # Connect to http://pokeapi.com/...
            
    # Build the dictionary to create the new Pokemon
            
    # Add it to the list of Pokemon

    @classmethod
    def run(self):
        pass
                
    @classmethod
    def standardize(self):
        # Build a Python dictionary that categorizes all Pokemon into any and ALL types in which they belong 
        
        # If a Pokemon has multiple types

        # Create a Pokemon dictionary for every type they belong to.
# Out:
#   File "<ipython-input-77-b2058aff42c2>", line 46
#     # Create a Pokemon dictionary for every type they belong to.
#                                                                  ^
# IndentationError: expected an indented block

# %%
import requests



def pokeapi(x):
    poke=['zapdos','jynx','abra']
    for y in poke:
        y==x

        x = []

        data= requests.get('https://pokeapi.co/api/v2/pokemon/'+x).json()

        ability=[(data['abilities'][0]['ability']['name']),(data['abilities'][1]['ability']['name'])]
        ty=[data['types'][0]['type']['name']]
        he=[data['height']]
        we=[data["weight"]]

        x.append({'abilities':ability})
        x.append({'height':he})
        x.append({'weight':we})
        x.append({'types':ty})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-82-8e0ef35aad61> in <module>
#       3
#       4 for y in poke:
# ----> 5     y==x
#       6
#       7     x = []
#
# NameError: name 'x' is not defined
